# %% [markdown]
# # Exploration Notebook
#
# Use this notebook to inspect smartwatch time-series data, validate preprocessing steps, and prototype feature engineering for risk prediction.

# %%
import pandas as pd
import numpy as np

print('Exploration notebook ready')
